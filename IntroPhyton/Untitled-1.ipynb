# %%
cont=int(1)
while cont<=500 :
    print(f'{cont}\n')
    cont= cont+1
    if cont % 5 == 0 +1:
        print("-----------------------------")
    if cont % 9 == 0 :
        print(f"(multiplo de 9):",end="")
    if cont % 4 == 0 :
        print(f"(multiplo de 4):",end="")
# Out:
# 1
#
# 2
#
# 3
#
# (multiplo de 4):4
#
# 5
#
# -----------------------------
# 6
#
# 7
#
# (multiplo de 4):8
#
# (multiplo de 9):9
#
# 10
#
# -----------------------------
# 11
#
# (multiplo de 4):12
#
# 13
#
# 14
#
# 15
#
# -----------------------------
# (multiplo de 4):16
#
# 17
#
# (multiplo de 9):18
#
# 19
#
# (multiplo de 4):20
#
# -----------------------------
# 21
#
# 22
#
# 23
#
# (multiplo de 4):24
#
# 25
#
# -----------------------------
# 26
#
# (multiplo de 9):27
#
# (multiplo de 4):28
#
# 29
#
# 30
#
# -----------------------------
# 31
#
# (multiplo de 4):32
#
# 33
#
# 34
#
# 35
#
# -----------------------------
# (multiplo de 9):(multiplo de 4):36
#
# 37
#
# 38
#
# 39
#
# (multiplo de 4):40
#
# -----------------------------
# 41
#
# 42
#
# 43
#
# (multiplo de 4):44
#
# (multiplo de 9):45
#
# -----------------------------
# 46
#
# 47
#
# (multiplo de 4):48
#
# 49
#
# 50
#
# -----------------------------
# 51
#
# (multiplo de 4):52
#
# 53
#
# (multiplo de 9):54
#
# 55
#
# ...
